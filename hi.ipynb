# %%
my_ppl2={
    "name":"gech"
}
res=[name for name in my_ppl2]
print()

# %% [markdown]
# <h1>hellow </h1>

# %%
from datetime import datetime
print(datetime.now())
name=input("your name:")
print(name)
num1=int(input("enter the number 1 :"))
num2=int(input("enter the num2"))
sum=num1+num2
print(name,sum)
gech_stacks=["heheheh","fmefmeo","next js"]
for i in gech_stacks:
    print(i)
# Out:
# 2026-02-19 16:27:20.247128
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 from datetime import datetime
#       2 print(datetime.now())
# ----> 3 name=input("your name:")
#       4 print(name)
#       5 num1=int(input("enter the number 1 :"))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# ...

# %%
print("hello")
# Out:
# hello
